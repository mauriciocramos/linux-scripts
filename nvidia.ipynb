# %%
import sys
sys.path.insert(1, '/home/mauricio/code/mcr')
from mcr.util import glimpse

# %%
import pandas as pd
nvidia = pd.read_csv('/home/mauricio/nvidia-gpu.csv', na_values=[' [N/A]', ' N/A'], parse_dates=['timestamp'])
nvidia.columns = nvidia.columns.str.strip()
nvidia.loc[:, nvidia.dtypes=='object'] = nvidia.loc[:, nvidia.dtypes=='object'].apply(lambda x: x.str.strip())
pd.options.display.max_columns=nvidia.columns.size
pd.options.display.max_rows=nvidia.columns.size
pd.options.display.max_colwidth=1000

# %%
glimpse(nvidia)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 385 entries, 0 to 384
# Columns: 65 entries, timestamp to clocks.max.memory [MHz]
# dtypes: datetime64[ns](1), float64(3), int64(13), object(48)
# memory usage: 1.2 MB
#                                                   field non-null count  \
# 0                                accounting.buffer_size            385
# 1                                       accounting.mode            385
# 2                         clocks.current.graphics [MHz]            385
# 3                           clocks.current.memory [MHz]            385
# 4                               clocks.current.sm [MHz]            385
# 5                            clocks.current.video [MHz]            385
# 6                             clocks.max.graphics [MHz]            385
# 7                               clocks.max.memory [MHz]            385
# 8                                   clocks.max.sm [MHz]            385
# ...
